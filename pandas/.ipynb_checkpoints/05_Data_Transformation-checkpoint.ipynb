# %%
import pandas as pd

# %%
df = pd.read_csv("movies.csv")

# %%
df_2 = df.sort_values(["critic_score","audience_score"],ascending=False).copy()

# %%
df_2
# Out:
#                                  movieId                           movieTitle  \
# 0   3f297cf0-2e9d-31c0-b566-6676dd8548b2                              Titanic
# 1   ed95f56a-dc82-3197-97fd-763ab02d032a                            Contagion
# 3   7712badd-e5ec-3d28-8787-7fd6301f5a0a                             The Wave
# 4   65abd2ca-6095-3acc-b072-00443c4c1fb5                       The Impossible
# 2   f639ff01-58ec-3847-95a0-c1b1b8de5550                    Deepwater Horizon
# 5   5cf3dfaa-1396-3c86-85ec-3173cad39f22                            Black Sea
# 7   d1e52d53-1447-337e-8e14-d20f8a856093               The Poseidon Adventure
# 6   c4b30fa1-9036-3c88-a8b1-2731bf3afc38                            Greenland
# 8   4f1acbb5-6c09-330a-87b9-530a698c5e65                            Sharknado
# 9   2645a114-3f86-3f6e-8da1-74f0804df941                              Airport
# 11  d3d3c30b-9116-3d4b-978b-1a9196e35309                      The Burning Sea
# ...

# %%
df_2.reset_index()
# Out:
#     index                               movieId  \
# 0       0  3f297cf0-2e9d-31c0-b566-6676dd8548b2
# 1       1  ed95f56a-dc82-3197-97fd-763ab02d032a
# 2       3  7712badd-e5ec-3d28-8787-7fd6301f5a0a
# 3       4  65abd2ca-6095-3acc-b072-00443c4c1fb5
# 4       2  f639ff01-58ec-3847-95a0-c1b1b8de5550
# 5       5  5cf3dfaa-1396-3c86-85ec-3173cad39f22
# 6       7  d1e52d53-1447-337e-8e14-d20f8a856093
# 7       6  c4b30fa1-9036-3c88-a8b1-2731bf3afc38
# 8       8  4f1acbb5-6c09-330a-87b9-530a698c5e65
# 9       9  2645a114-3f86-3f6e-8da1-74f0804df941
# 10     11  d3d3c30b-9116-3d4b-978b-1a9196e35309
# 11     12  6898bf3d-32d5-3ac6-aab4-f202d4fe56ba
# 12     10  e9132f51-8de9-3e1f-b390-699bce9cde57
# 13     13  4a07a9a5-846c-309d-9c59-792757fda630
# 14     14  3a886fc1-2e8f-37a5-9687-29e0e2e89e72
# 15     15  a9989888-e0d4-38cc-981f-be80a7bd59b8
# 16     16  b7ecb431-d281-3ece-ac8a-fd716d125c91
# 17     48  efb3cf40-69f9-33bf-ae1b-264bc6e9f7ee
# ...

# %%
df_2.reset_index(drop=True,inplace=True) 
df_2
# Out:
#                                  movieId                           movieTitle  \
# 0   3f297cf0-2e9d-31c0-b566-6676dd8548b2                              Titanic
# 1   ed95f56a-dc82-3197-97fd-763ab02d032a                            Contagion
# 2   7712badd-e5ec-3d28-8787-7fd6301f5a0a                             The Wave
# 3   65abd2ca-6095-3acc-b072-00443c4c1fb5                       The Impossible
# 4   f639ff01-58ec-3847-95a0-c1b1b8de5550                    Deepwater Horizon
# 5   5cf3dfaa-1396-3c86-85ec-3173cad39f22                            Black Sea
# 6   d1e52d53-1447-337e-8e14-d20f8a856093               The Poseidon Adventure
# 7   c4b30fa1-9036-3c88-a8b1-2731bf3afc38                            Greenland
# 8   4f1acbb5-6c09-330a-87b9-530a698c5e65                            Sharknado
# 9   2645a114-3f86-3f6e-8da1-74f0804df941                              Airport
# 10  d3d3c30b-9116-3d4b-978b-1a9196e35309                      The Burning Sea
# ...
