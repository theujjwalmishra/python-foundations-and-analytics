# %%
import pandas as pd

# %%
url = "movies.csv"
df = pd.read_csv(url)

#print(df.head())
df.columns
# Out:
# Index(['movieId', 'movieTitle', 'movieYear', 'movieURL', 'movieRank',
#        'critic_score', 'audience_score'],
#       dtype='str')
