# %%
import pandas as pd

# %%
df = pd.DataFrame({
"Department": ["HR", "HR", "IT", "IT", "Marketing", "Marketing", "Sales", "Sales"],
"Team": ["A", "A", "B", "B", "C", "C", "D", "D"],
"Gender": ["M", "F", "M", "F", "M", "F", "M", "F"],
"Salary": [85, 90, 78, 85, 92, 88, 75, 80],
"Age": [23, 25, 30, 22, 28, 26, 21, 27],
"JoinDate": pd.to_datetime([
"2020-01-10", "2020-02-15", "2021-03-20", "2021-04-10",
"2020-05-30", "2020-06-25", "2021-07-15", "2021-08-01"
])
})

# %%
df
# Out:
#   Department Team Gender  Salary  Age   JoinDate
# 0         HR    A      M      85   23 2020-01-10
# 1         HR    A      F      90   25 2020-02-15
# 2         IT    B      M      78   30 2021-03-20
# 3         IT    B      F      85   22 2021-04-10
# 4  Marketing    C      M      92   28 2020-05-30
# 5  Marketing    C      F      88   26 2020-06-25
# 6      Sales    D      M      75   21 2021-07-15
# 7      Sales    D      F      80   27 2021-08-01

# %%
df.groupby("Department")["Age"].agg(["mean","min","max"])
# Out:
#             mean  min  max
# Department
# HR          24.0   23   25
# IT          26.0   22   30
# Marketing   27.0   26   28
# Sales       24.0   21   27

# %%
df
# Out:
#   Department Team Gender  Salary  Age   JoinDate
# 0         HR    A      M      85   23 2020-01-10
# 1         HR    A      F      90   25 2020-02-15
# 2         IT    B      M      78   30 2021-03-20
# 3         IT    B      F      85   22 2021-04-10
# 4  Marketing    C      M      92   28 2020-05-30
# 5  Marketing    C      F      88   26 2020-06-25
# 6      Sales    D      M      75   21 2021-07-15
# 7      Sales    D      F      80   27 2021-08-01

# %%
df.groupby(["Team","Department"])["Salary"].agg(
    Avg_Salary="mean",
    Max_Salary="max",
    Total_Count="count"
)
# Out:
#                  Avg_Salary  Max_Salary  Total_Count
# Team Department
# A    HR                87.5          90            2
# B    IT                81.5          85            2
# C    Marketing         90.0          92            2
# D    Sales             77.5          80            2

# %%
df.groupby("Department")["Age"].agg("mean")
# Out:
# Department
# HR           24.0
# IT           26.0
# Marketing    27.0
# Sales        24.0
# Name: Age, dtype: float64

# %%
df.groupby("Department")["Age"].transform("max")
# Out:
# 0    25
# 1    25
# 2    30
# 3    30
# 4    28
# 5    28
# 6    27
# 7    27
# Name: Age, dtype: int64
