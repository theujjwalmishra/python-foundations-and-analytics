# %%
import pandas as pd

# %%
data = [
    ["Alice",25],
    ["Bob",45],
    ["Charlie",45]
]
#df = pd.DataFrame(data)
#ds = pd.DataFrame(data,columns=["Name","Age"])
ds = pd.DataFrame(data,columns=["Name","Age"])
print(ds)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   45
# 2  Charlie   45
