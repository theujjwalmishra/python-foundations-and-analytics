# %%
import pandas as pd

# %%
series = pd.Series([70,45,26])
print(series)
# Out:
# 0    70
# 1    45
# 2    26
# dtype: int64

# %%
seres = pd.Series([70,89,98] , index=["Om","Vom","Ram"])
print(seres)
# Out:
# Om     70
# Vom    89
# Ram    98
# dtype: int64

# %%
print(seres["Om"])# I can even find numbers by there variables
# Out:
# 70

# %%
data = {
    "name" : ["Om","Vom","Ram"],
    "age" : [23,43,53],
    "city" : ["Agra","Delhi","Kadar"]
}

data = pd.DataFrame(data)
print(data)
# Out:
#   name  age   city
# 0   Om   23   Agra
# 1  Vom   43  Delhi
# 2  Ram   53  Kadar

# %%
print(data.iloc[0:2])
# Out:
#   name  age   city
# 0   Om   23   Agra
# 1  Vom   43  Delhi

# %%
data.iloc[0]
# Out:
# name      Om
# age       23
# city    Agra
# Name: 0, dtype: object
