# %%
import numpy as np

# %%
arr = np.array([[1,2,3],[22,42,12],[5,6,7],[6,89,54]])
print(arr)
# Out:
# [[ 1  2  3]
#  [22 42 12]
#  [ 5  6  7]
#  [ 6 89 54]]

# %%
flat = arr.flatten()
print(flat)
# Out:
# [ 1  2  3 22 42 12  5  6  7  6 89 54]

# %%
print(flat[0]) # it is indexing
print(flat[0:3]) # it is slicing
# Out:
# 1
# [1 2 3]

# %%
b = flat[3:7]
b[0] = 40
print(flat)
# Out:
# [ 1  2  3 40 42 12  5  6  7  6 89 54]

# %%
mask = flat> 23
print(flat[mask])
# Out:
# [40 42 89 54]
