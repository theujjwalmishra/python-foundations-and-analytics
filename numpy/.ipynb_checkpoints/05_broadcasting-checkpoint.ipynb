# %%
import numpy as np

# %%
# Vectorization

# %%
arr = np.array ([1,2,4,5])
result = arr ** 3
print(result)
# Out:
# [  1   8  64 125]

# %%
mean = np.mean(arr)
print(mean)
# Out:
# 3.0

# %%
arr_2 = np.array([2,4,14,54])
sum = np.sum(arr + arr_2)
print(sum)
# Out:
# 86

# %%
# Broadcasting
