# %%
import numpy as np

# %%
arr = np.array([[[4,5,6],[3,3,5]],[[7,5,7],[10,54,6]]])
print(arr)
# Out:
# [[[ 4  5  6]
#   [ 3  3  5]]
#
#  [[ 7  5  7]
#   [10 54  6]]]

# %%
print(arr[1,0,1:3])
# Out:
# [5 7]

# %%
print(arr[0,0,2])
# Out:
# 6
